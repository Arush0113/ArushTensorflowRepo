# %% [markdown]
# <a href="https://colab.research.google.com/github/Arush0113/ArushTensorflowRepo/blob/main/Week_3_Programming_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programming Assignment

# %% [markdown]
# ## Model validation on the Iris dataset

# %% [markdown]
# ### Instructions
#
# In this notebook, you will build, compile and fit a neural network model to the Iris dataset. You will also implement validation, regularisation and callbacks to improve your model.
#
# Some code cells are provided you in the notebook. You should avoid editing provided code, and make sure to execute the cells in order to avoid unexpected errors. Some cells begin with the line:
#
# `#### GRADED CELL ####`
#
# Don't move or edit this first line - this is what the automatic grader looks for to recognise graded cells. These cells require you to write your own code to complete them, and are automatically graded when you submit the notebook. Don't edit the function name or signature provided in these cells, otherwise the automatic grader might not function properly. Inside these graded cells, you can use any functions or classes that are imported below, but make sure you don't use any variables that are outside the scope of the function.
#
# ### How to submit
#
# Complete all the tasks you are asked for in the worksheet. When you have finished and are happy with your code, press the **Submit Assignment** button at the top of this notebook.
#
# ### Let's get started!
#
# We'll start running some imports, and loading the dataset. Do not edit the existing imports in the following cell. If you would like to make further Tensorflow imports, you should add them here.

# %%
#### PACKAGE IMPORTS ####

# Run this cell first to import all required packages. Do not make any imports elsewhere in the notebook
from numpy.random import seed
seed(8)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, model_selection 
# %matplotlib inline

# If you would like to make further imports from tensorflow, add them here
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.regularizers import l2

# %% [markdown]
# #### The Iris dataset
#
# In this assignment, you will use the [Iris dataset](https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html). It consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters. For a reference, see the following papers:
#
# - R. A. Fisher. "The use of multiple measurements in taxonomic problems". Annals of Eugenics. 7 (2): 179–188, 1936.
#
# Your goal is to construct a neural network that classifies each sample into the correct class, as well as applying validation and regularisation techniques.

# %% [markdown]
# #### Load and preprocess the data
#
# First read in the Iris dataset using `datasets.load_iris()`, and split the dataset into training and test sets.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def read_in_and_split_data(iris_data):
    """
    This function takes the Iris dataset as loaded by sklearn.datasets.load_iris(), and then 
    splits so that the training set includes 90% of the full dataset, with the test set 
    making up the remaining 10%.
    Your function should return a tuple (train_data, test_data, train_targets, test_targets) 
    of appropriately split training and test data and targets.
    
    If you would like to import any further packages to aid you in this task, please do so in the 
    Package Imports cell above.
    """
    data = iris_data['data']
    targets = iris_data['target']
    train_data, test_data, train_targets, test_targets = train_test_split(data, targets, test_size = 0.1)
    
    return train_data, test_data, train_targets, test_targets

# %%
# Run your function to generate the test and training data.

iris_data = datasets.load_iris()
train_data, test_data, train_targets, test_targets = read_in_and_split_data(iris_data)

# %% [markdown]
# We will now convert the training and test targets using a one hot encoder.

# %%
# Convert targets to a one-hot encoding

train_targets = tf.keras.utils.to_categorical(np.array(train_targets))
test_targets = tf.keras.utils.to_categorical(np.array(test_targets))

# %% [markdown]
# #### Build the neural network model

# %% [markdown]
# You can now construct a model to fit to the data. Using the Sequential API, build your model according to the following specifications:
#
# * The model should use the `input_shape` in the function argument to set the input size in the first layer.
# * The first layer should be a dense layer with 64 units.
# * The weights of the first layer should be initialised with the He uniform initializer.
# * The biases of the first layer should be all initially equal to one.
# * There should then be a further four dense layers, each with 128 units.
# * This should be followed with four dense layers, each with 64 units.
# * All of these Dense layers should use the ReLU activation function.
# * The output Dense layer should have 3 units and the softmax activation function.
#
# In total, the network should have 10 layers.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_model(input_shape):
    """
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """
    model = Sequential([
        Dense(64, activation = 'relu', kernel_initializer='he_uniform',bias_initializer='ones', input_shape = input_shape,),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(3, activation='softmax'),
    ])    
    return model

# %%
# Run your function to get the model

model = get_model(train_data[0].shape)

# %% [markdown]
# #### Compile the model
#
# You should now compile the model using the `compile` method. Remember that you need to specify an optimizer, a loss function and a metric to judge the performance of your model.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.


def compile_model(model):
    """
    This function takes in the model returned from your get_model function, and compiles it with an optimiser,
    loss function and metric.
    Compile the model using the Adam optimiser (with learning rate set to 0.0001), 
    the categorical crossentropy loss function and accuracy as the only metric. 
    Your function doesn't need to return anything; the model will be compiled in-place.
    """
    model.compile(optimizer = Adam(learning_rate=0.001), loss = categorical_crossentropy, metrics = ['accuracy'])

# %%
# Run your function to compile the model

compile_model(model)

# %% [markdown]
# #### Fit the model to the training data
#
# Now you should train the model on the Iris dataset, using the model's `fit` method.
# * Run the training for a fixed number of epochs, given by the function's `epochs` argument.
# * Return the training history to be used for plotting the learning curves.
# * Set the batch size to 40.
# * Set the validation set to be 15% of the training set.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def train_model(model, train_data, train_targets, epochs):
    """
    This function should train the model for the given number of epochs on the 
    train_data and train_targets. 
    Your function should return the training history, as returned by model.fit.
    """
    history = model.fit(train_data, train_targets, batch_size=64, epochs=epochs, validation_split=0.15)
    return history

# %%
# Run your function to train the model

history = train_model(model, train_data, train_targets, epochs=800)
# Out:
# Epoch 1/800
# 2/2 [==============================] - 0s 124ms/step - loss: 8.8361e-07 - accuracy: 1.0000 - val_loss: 0.6517 - val_accuracy: 0.9048
# Epoch 2/800
# 2/2 [==============================] - 0s 60ms/step - loss: 8.7419e-07 - accuracy: 1.0000 - val_loss: 0.6513 - val_accuracy: 0.9048
# Epoch 3/800
# 2/2 [==============================] - 0s 57ms/step - loss: 8.6269e-07 - accuracy: 1.0000 - val_loss: 0.6516 - val_accuracy: 0.9048
# Epoch 4/800
# 2/2 [==============================] - 0s 58ms/step - loss: 8.5433e-07 - accuracy: 1.0000 - val_loss: 0.6520 - val_accuracy: 0.9048
# Epoch 5/800
# 2/2 [==============================] - 0s 58ms/step - loss: 8.4701e-07 - accuracy: 1.0000 - val_loss: 0.6532 - val_accuracy: 0.9048
# Epoch 6/800
# 2/2 [==============================] - 0s 65ms/step - loss: 8.3550e-07 - accuracy: 1.0000 - val_loss: 0.6540 - val_accuracy: 0.9048
# Epoch 7/800
# 2/2 [==============================] - 0s 67ms/step - loss: 8.2609e-07 - accuracy: 1.0000 - val_loss: 0.6558 - val_accuracy: 0.9048
# Epoch 8/800
# 2/2 [==============================] - 0s 68ms/step - loss: 8.1877e-07 - accuracy: 1.0000 - val_loss: 0.6573 - val_accuracy: 0.9048
# Epoch 9/800
# 2/2 [==============================] - 0s 63ms/step - loss: 8.0936e-07 - accuracy: 1.0000 - val_loss: 0.6582 - val_accuracy: 0.9048
# Epoch 10/800
# 2/2 [==============================] - 0s 62ms/step - loss: 8.0100e-07 - accuracy: 1.0000 - val_loss: 0.6591 - val_accuracy: 0.9048
# Epoch 11/800
# 2/2 [==============================] - 0s 62ms/step - loss: 7.8949e-07 - accuracy: 1.0000 - val_loss: 0.6596 - val_accuracy: 0.9048
# Epoch 12/800
# 2/2 [==============================] - 0s 66ms/step - loss: 7.8322e-07 - accuracy: 1.0000 - val_loss: 0.6598 - val_accuracy: 0.9048
# Epoch 13/800
# 2/2 [==============================] - 0s 60ms/step - loss: 7.7381e-07 - accuracy: 1.0000 - val_loss: 0.6602 - val_accuracy: 0.9048
# Epoch 14/800
# 2/2 [==============================] - 0s 66ms/step - loss: 7.6858e-07 - accuracy: 1.0000 - val_loss: 0.6603 - val_accuracy: 0.9048
# Epoch 15/800
# 2/2 [==============================] - 0s 63ms/step - loss: 7.6022e-07 - accuracy: 1.0000 - val_loss: 0.6605 - val_accuracy: 0.9048
# Epoch 16/800
# 2/2 [==============================] - 0s 62ms/step - loss: 7.5290e-07 - accuracy: 1.0000 - val_loss: 0.6611 - val_accuracy: 0.9048
# Epoch 17/800
# 2/2 [==============================] - 0s 64ms/step - loss: 7.4244e-07 - accuracy: 1.0000 - val_loss: 0.6604 - val_accuracy: 0.9048
# Epoch 18/800
# 2/2 [==============================] - 0s 74ms/step - loss: 7.3721e-07 - accuracy: 1.0000 - val_loss: 0.6593 - val_accuracy: 0
800
# 2/2 [==============================] - 0s 63ms/step - loss: 5.8977e-07 - accuracy: 1.0000 - val_loss: 0.6678 - val_accuracy: 0.9048
# Epoch 44/800
# 2/2 [==============================] - 0s 63ms/step - loss: 5.8768e-07 - accuracy: 1.0000 - val_loss: 0.6686 - val_accuracy: 0.9048
# Epoch 45/800
# 2/2 [==============================] - 0s 63ms/step - loss: 5.8036e-07 - accuracy: 1.0000 - val_loss: 0.6705 - val_accuracy: 0.9048
# Epoch 46/800
# 2/2 [==============================] - 0s 66ms/step - loss: 5.7513e-07 - accuracy: 1.0000 - val_loss: 0.6714 - val_accuracy: 0.9048
# Epoch 47/800
# 2/2 [==============================] - 0s 65ms/step - loss: 5.6990e-07 - accuracy: 1.0000 - val_loss: 0.6722 - val_accuracy: 0.9048
# Epoch 48/800
# 2/2 [==============================] - 0s 63ms/step - loss: 5.6781e-07 - accuracy: 1.0000 - val_loss: 0.6724 - val_accuracy: 0.9048
# Epoch 49/800
# 2/2 [==============================] - 0s 61ms/step - loss: 5.6258e-07 - accuracy: 1.0000 - val_loss: 0.6728 - val_accuracy: 0.9048
# Epoch 50/800
# 2/2 [==============================] - 0s 63ms/step - loss: 5.5944e-07 - accuracy: 1.0000 - val_loss: 0.6737 - val_accuracy: 0.9048
# Epoch 51/800
# 2/2 [==============================] - 0s 63ms/step - loss: 5.5212e-07 - accuracy: 1.0000 - val_loss: 0.6739 - val_accuracy: 0.9048
# Epoch 52/800
# 2/2 [==============================] - 0s 62ms/step - loss: 5.5108e-07 - accuracy: 1.0000 - val_loss: 0.6737 - val_accuracy: 0.9048
# Epoch 53/800
# 2/2 [==============================] - 0s 59ms/step - loss: 5.4585e-07 - accuracy: 1.0000 - val_loss: 0.6733 - val_accuracy: 0.9048
# Epoch 54/800
# 2/2 [==============================] - 0s 63ms/step - loss: 5.4271e-07 - accuracy: 1.0000 - val_loss: 0.6730 - val_accuracy: 0.9048
# Epoch 55/800
# 2/2 [==============================] - 0s 65ms/step - loss: 5.3749e-07 - accuracy: 1.0000 - val_loss: 0.6734 - val_accuracy: 0.9048
# Epoch 56/800
# 2/2 [==============================] - 0s 66ms/step - loss: 5.3226e-07 - accuracy: 1.0000 - val_loss: 0.6741 - val_accuracy: 0.9048
# Epoch 57/800
# 2/2 [==============================] - 0s 58ms/step - loss: 5.2912e-07 - accuracy: 1.0000 - val_loss: 0.6745 - val_accuracy: 0.9048
# Epoch 58/800
# 2/2 [==============================] - 0s 58ms/step - loss: 5.2598e-07 - accuracy: 1.0000 - val_loss: 0.6737 - val_accuracy: 0.9048
# Epoch 59/800
# 2/2 [==============================] - 0s 57ms/step - loss: 5.2285e-07 - accuracy: 1.0000 - val_loss: 0.6730 - val_accuracy: 0.9048
# Epoch 60/800
# 2/2 [==============================] - 0s 76ms/step - loss: 5.1866e-07 - accuracy: 1.0000 - val_loss: 0.6733 - val_accuracy: 0.9048
# Epoch 61/800
# 2/2 [==============================] - 0s 65ms/step - loss: 5.1762e-07 - accuracy: 1.0000 - val_loss: 0.6748 - val_accuracy: 0.9048
# Epoch 62/800
# 2/2 [==============================] - 0s 60ms/step - loss: 5.1239e-07 - accuracy: 1.0000 - val_loss: 0.6754 - val_accuracy: 0.9048
# Epoch 63/800
# 2/2 [==============================] - 0s 62ms/step - loss: 5.0821e-07 - accuracy: 1.0000 - val_loss: 0.6754 - val_accuracy: 0.9048
# Epoch 64/800
# 2/2 [==============================] - 0s 62ms/step - loss: 5.0611e-07 - accuracy: 1.0000 - val_loss: 0.6750 - val_accuracy: 0.9048
# Epoch 65/800
# 2/2 [==============================] - 0s 61ms/step - loss: 5.0193e-07 - accuracy: 1.0000 - val_loss: 0.6750 - val_accuracy: 0.9048
# Epoch 66/800
# 2/2 [==============================] - 0s 66ms/step - loss: 4.9670e-07 - accuracy: 1.0000 - val_loss: 0.6756 - val_accuracy: 0.9048
# Epoch 67/800
# 2/2 [==============================] - 0s 61ms/step - loss: 4.9357e-07 - accuracy: 1.0000 - val_loss: 0.6762 - val_accuracy: 0.9048
# Epoch 68/800
# 2/2 [==============================] - 0s 65ms/step - loss: 4.9147e-07 - accuracy: 1.0000 - val_loss: 0.6768 - val_accuracy: 0.9048
# Epoch 69/800
# 2/2 [==============================] - 0s 62ms/step - loss: 4.8938e-07 - accuracy: 1.0000 - val_loss: 0.6778 - val_accuracy: 0.9048
# Epoch 70/800
# 2/2 [==============================] - 0s 58ms/step - loss: 4.8520e-07 - accuracy: 1.0000 - val_loss: 0.6775 - val_accuracy: 0.9048
# Epoch 71/800
# 2/2 [==============================] - 0s 60ms/step - loss: 4.8311e-07 - accuracy: 1.0000 - val_loss: 0.6771 - val_accuracy: 0.9048
# Epoch 72/800
# 2/2 [==============================] - 0s 60ms/step - loss: 4.7893e-07 - accuracy: 1.0000 - val_loss: 0.6767 - val_accuracy: 0.9048
# Epoch 73/800
# 2/2 [==============================] - 0s 61ms/step - loss: 4.7579e-07 - accuracy: 1.0000 - val_loss: 0.6776 - val_accuracy: 0.9048
# Epoch 74/800
# 2/2 [==============================] - 0s 66ms/step - loss: 4.7370e-07 - accuracy: 1.0000 - val_loss: 0.6779 - val_accuracy: 0.9048
# Epoch 75/800
# 2/2 [==============================] - 0s 60ms/step - loss: 4.7056e-07 - accuracy: 1.0000 - val_loss: 0.6780 - val_accuracy: 0.9048
# Epoch 76/800
# 2/2 [==============================] - 0s 63ms/step - loss: 4.6847e-07 - accuracy: 1.0000 - val_loss: 0.6791 - val_accuracy: 0.9048
# Epoch 77/800
# 2/2 [==============================] - 0s 70ms/step - loss: 4.6638e-07 - accuracy: 1.0000 - val_loss: 0.6794 - val_accuracy: 0.9048
# Epoch 78/800
# 2/2 [==============================] - 0s 58ms/step - loss: 4.6324e-07 - accuracy: 1.0000 - val_loss: 0.6793 - val_accuracy: 0.9048
# Epoch 79/800
# 2/2 [==============================] - 0s 61ms/step - loss: 4.6010e-07 - accuracy: 1.0000 - val_loss: 0.6791 - val_accuracy: 0.9048
# Epoch 80/800
# 2/2 [==============================] - 0s 58ms/step - loss: 4.5592e-07 - accuracy: 1.0000 - val_loss: 0.6791 - val_accuracy: 0.9048
# Epoch 81/800
# 2/2 [==============================] - 0s 60ms/step - loss: 4.5383e-07 - accuracy: 1.0000 - val_loss: 0.6792 - val_accuracy: 0.9048
# Epoch 82/800
# 2/2 [==============================] - 0s 62ms/step - loss: 4.5069e-07 - accuracy: 1.0000 - val_loss: 0.6799 - val_accuracy: 0.9048
# Epoch 83/800
# 2/2 [==============================] - 0s 64ms/step - loss: 4.4965e-07 - accuracy: 1.0000 - val_loss: 0.6806 - val_accuracy: 0.9048
# Epoch 84/800
# 2/2 [==============================] - 0s 62ms/step - loss: 4.4546e-07 - accuracy: 1.0000 - val_loss: 0.6810 - val_accuracy: 0.9048
# Epoch 85/800
# 2/2 [==============================] - 0s 64ms/step - loss: 4.4233e-07 - accuracy: 1.0000 - val_loss: 0.6807 - val_accuracy: 0.9048
# Epoch 86/800
# 2/2 [==============================] - 0s 68ms/step - loss: 4.4233e-07 - accuracy: 1.0000 - val_loss: 0.6807 - val_accuracy: 0.9048
# Epoch 87/800
# 2/2 [==============================] - 0s 61ms/step - loss: 4.3919e-07 - accuracy: 1.0000 - val_loss: 0.6817 - val_accuracy: 0.9048
# Epoch 88/800
# 2/2 [==============================] - 0s 64ms/step - loss: 4.3710e-07 - accuracy: 1.0000 - val_loss: 0.6819 - val_accuracy: 0.9048
# Epoch 89/800
# 2/2 [==============================] - 0s 62ms/step - loss: 4.3292e-07 - accuracy: 1.0000 - val_loss: 0.6821 - val_accuracy: 0.9048
# Epoch 90/800
# 2/2 [==============================] - 0s 61ms/step - loss: 4.3187e-07 - accuracy: 1.0000 - val_loss: 0.6824 - val_accuracy: 0.9048
# Epoch 91/800
# 2/2 [==============================] - 0s 67ms/step - loss: 4.2873e-07 - accuracy: 1.0000 - val_loss: 0.6834 - val_accuracy: 0.9048
# Epoch 92/800
# 2/2 [==============================] - 0s 64ms/step - loss: 4.2769e-07 - accuracy: 1.0000 - val_loss: 0.6835 - val_accuracy: 0.9048
# Epoch 93/800
# 2/2 [==============================] - 0s 64ms/step - loss: 4.2560e-07 - accuracy: 1.0000 - val_loss: 0.6838 - val_accuracy: 0.9048
# Epoch 94/800
# 2/2 [==============================] - 0s 67ms/step - loss: 4.2246e-07 - accuracy: 1.0000 - val_loss: 0.6839 - val_accuracy: 0.9048
# Epoch 95/800
# 2/2 [==============================] - 0s 70ms/step - loss: 4.2037e-07 - accuracy: 1.0000 - val_loss: 0.6841 - val_accuracy: 0.9048
# Epoch 96/800
# 2/2 [==============================] - 0s 70ms/step - loss: 4.1828e-07 - accuracy: 1.0000 - val_loss: 0.6845 - val_accuracy: 0.9048
# Epoch 97/800
# 2/2 [==============================] - 0s 62ms/step - loss: 4
800
# 2/2 [==============================] - 0s 67ms/step - loss: 2.9489e-07 - accuracy: 1.0000 - val_loss: 0.7100 - val_accuracy: 0.9048
# Epoch 173/800
# 2/2 [==============================] - 0s 63ms/step - loss: 2.9489e-07 - accuracy: 1.0000 - val_loss: 0.7108 - val_accuracy: 0.9048
# Epoch 174/800
# 2/2 [==============================] - 0s 71ms/step - loss: 2.9489e-07 - accuracy: 1.0000 - val_loss: 0.7112 - val_accuracy: 0.9048
# Epoch 175/800
# 2/2 [==============================] - 0s 64ms/step - loss: 2.9175e-07 - accuracy: 1.0000 - val_loss: 0.7113 - val_accuracy: 0.9048
# Epoch 176/800
# 2/2 [==============================] - 0s 64ms/step - loss: 2.9175e-07 - accuracy: 1.0000 - val_loss: 0.7115 - val_accuracy: 0.9048
# Epoch 177/800
# 2/2 [==============================] - 0s 73ms/step - loss: 2.9070e-07 - accuracy: 1.0000 - val_loss: 0.7113 - val_accuracy: 0.9048
# Epoch 178/800
# 2/2 [==============================] - 0s 61ms/step - loss: 2.8861e-07 - accuracy: 1.0000 - val_loss: 0.7110 - val_accuracy: 0.9048
# Epoch 179/800
# 2/2 [==============================] - 0s 62ms/step - loss: 2.8861e-07 - accuracy: 1.0000 - val_loss: 0.7108 - val_accuracy: 0.9048
# Epoch 180/800
# 2/2 [==============================] - 0s 63ms/step - loss: 2.8861e-07 - accuracy: 1.0000 - val_loss: 0.7110 - val_accuracy: 0.9048
# Epoch 181/800
# 2/2 [==============================] - 0s 62ms/step - loss: 2.8757e-07 - accuracy: 1.0000 - val_loss: 0.7121 - val_accuracy: 0.9048
# Epoch 182/800
# 2/2 [==============================] - 0s 62ms/step - loss: 2.8757e-07 - accuracy: 1.0000 - val_loss: 0.7135 - val_accuracy: 0.9048
# Epoch 183/800
# 2/2 [==============================] - 0s 67ms/step - loss: 2.8652e-07 - accuracy: 1.0000 - val_loss: 0.7143 - val_accuracy: 0.9048
# Epoch 184/800
# 2/2 [==============================] - 0s 61ms/step - loss: 2.8443e-07 - accuracy: 1.0000 - val_loss: 0.7148 - val_accuracy: 0.9048
# Epoch 185/800
# 2/2 [==============================] - 0s 62ms/step - loss: 2.8129e-07 - accuracy: 1.0000 - val_loss: 0.7149 - val_accuracy: 0.9048
# Epoch 186/800
# 2/2 [==============================] - 0s 62ms/step - loss: 2.8025e-07 - accuracy: 1.0000 - val_loss: 0.7147 - val_accuracy: 0.9048
# Epoch 187/800
# 2/2 [==============================] - 0s 64ms/step - loss: 2.8025e-07 - accuracy: 1.0000 - val_loss: 0.7146 - val_accuracy: 0.9048
# Epoch 188/800
# 2/2 [==============================] - 0s 65ms/step - loss: 2.7815e-07 - accuracy: 1.0000 - val_loss: 0.7147 - val_accuracy: 0.9048
# Epoch 189/800
# 2/2 [==============================] - 0s 60ms/step - loss: 2.7711e-07 - accuracy: 1.0000 - val_loss: 0.7148 - val_accuracy: 0.9048
# Epoch 190/800
# 2/2 [==============================] - 0s 64ms/step - loss: 2.7606e-07 - accuracy: 1.0000 - val_loss: 0.7150 - val_accuracy: 0.9048
# Epoch 191/800
# 2/2 [==============================] - 0s 68ms/step - loss: 2.7606e-07 - accuracy: 1.0000 - val_loss: 0.7152 - val_accuracy: 0.9048
# Epoch 192/800
# 2/2 [==============================] - 0s 63ms/step - loss: 2.7397e-07 - accuracy: 1.0000 - val_loss: 0.7156 - val_accuracy: 0.9048
# Epoch 193/800
# 2/2 [==============================] - 0s 64ms/step - loss: 2.7293e-07 - accuracy: 1.0000 - val_loss: 0.7160 - val_accuracy: 0.9048
# Epoch 194/800
# 2/2 [==============================] - 0s 67ms/step - loss: 2.7293e-07 - accuracy: 1.0000 - val_loss: 0.7162 - val_accuracy: 0.9048
# Epoch 195/800
# 2/2 [==============================] - 0s 67ms/step - loss: 2.7188e-07 - accuracy: 1.0000 - val_loss: 0.7167 - val_accuracy: 0.9048
# Epoch 196/800
# 2/2 [==============================] - 0s 71ms/step - loss: 2.7083e-07 - accuracy: 1.0000 - val_loss: 0.7171 - val_accuracy: 0.9048
# Epoch 197/800
# 2/2 [==============================] - 0s 63ms/step - loss: 2.7083e-07 - accuracy: 1.0000 - val_loss: 0.7170 - val_accuracy: 0.9048
# Epoch 198/800
# 2/2 [==============================] - 0s 66ms/step - loss: 2.6979e-07 - accuracy: 1.0000 - val_loss: 0.7169 - val_accuracy: 0.9048
# Epoch 199/800
# 2/2 [==============================] - 0s 66ms/step - loss: 2.6979e-07 - accuracy: 1.0000 - val_loss: 0.7169 - val_accuracy: 0.9048
# Epoch 200/800
# 2/2 [==============================] - 0s 62ms/step - loss: 2.6665e-07 - accuracy: 1.0000 - val_loss: 0.7177 - val_accuracy: 0.9048
# Epoch 201/800
# 2/2 [==============================] - 0s 65ms/step - loss: 2.6665e-07 - accuracy: 1.0000 - val_loss: 0.7180 - val_accuracy: 0.9048
# Epoch 202/800
# 2/2 [==============================] - 0s 63ms/step - loss: 2.6561e-07 - accuracy: 1.0000 - val_loss: 0.7181 - val_accuracy: 0.9048
# Epoch 203/800
# 2/2 [==============================] - 0s 71ms/step - loss: 2.6561e-07 - accuracy: 1.0000 - val_loss: 0.7186 - val_accuracy: 0.9048
# Epoch 204/800
# 2/2 [==============================] - 0s 63ms/step - loss: 2.6247e-07 - accuracy: 1.0000 - val_loss: 0.7186 - val_accuracy: 0.9048
# Epoch 205/800
# 2/2 [==============================] - 0s 60ms/step - loss: 2.6142e-07 - accuracy: 1.0000 - val_loss: 0.7187 - val_accuracy: 0.9048
# Epoch 206/800
# 2/2 [==============================] - 0s 64ms/step - loss: 2.6142e-07 - accuracy: 1.0000 - val_loss: 0.7188 - val_accuracy: 0.9048
# Epoch 207/800
# 2/2 [==============================] - 0s 72ms/step - loss: 2.6142e-07 - accuracy: 1.0000 - val_loss: 0.7186 - val_accuracy: 0.9048
# Epoch 208/800
# 2/2 [==============================] - 0s 65ms/step - loss: 2.6142e-07 - accuracy: 1.0000 - val_loss: 0.7195 - val_accuracy: 0.9048
# Epoch 209/800
# 2/2 [==============================] - 0s 66ms/step - loss: 2.5933e-07 - accuracy: 1.0000 - val_loss: 0.7207 - val_accuracy: 0.9048
# Epoch 210/800
# 2/2 [==============================] - 0s 60ms/step - loss: 2.5933e-07 - accuracy: 1.0000 - val_loss: 0.7214 - val_accuracy: 0.9048
# Epoch 211/800
# 2/2 [==============================] - 0s 92ms/step - loss: 2.5933e-07 - accuracy: 1.0000 - val_loss: 0.7218 - val_accuracy: 0.9048
# Epoch 212/800
# 2/2 [==============================] - 0s 69ms/step - loss: 2.5515e-07 - accuracy: 1.0000 - val_loss: 0.7220 - val_accuracy: 0.9048
# Epoch 213/800
# 2/2 [==============================] - 0s 63ms/step - loss: 2.5410e-07 - accuracy: 1.0000 - val_loss: 0.7219 - val_accuracy: 0.9048
# Epoch 214/800
# 2/2 [==============================] - 0s 62ms/step - loss: 2.5515e-07 - accuracy: 1.0000 - val_loss: 0.7214 - val_accuracy: 0.9048
# Epoch 215/800
# 2/2 [==============================] - 0s 63ms/step - loss: 2.5306e-07 - accuracy: 1.0000 - val_loss: 0.7214 - val_accuracy: 0.9048
# Epoch 216/800
# 2/2 [==============================] - 0s 67ms/step - loss: 2.5201e-07 - accuracy: 1.0000 - val_loss: 0.7215 - val_accuracy: 0.9048
# Epoch 217/800
# 2/2 [==============================] - 0s 61ms/step - loss: 2.5097e-07 - accuracy: 1.0000 - val_loss: 0.7228 - val_accuracy: 0.9048
# Epoch 218/800
# 2/2 [==============================] - 0s 59ms/step - loss: 2.4992e-07 - accuracy: 1.0000 - val_loss: 0.7235 - val_accuracy: 0.9048
# Epoch 219/800
# 2/2 [==============================] - 0s 75ms/step - loss: 2.4992e-07 - accuracy: 1.0000 - val_loss: 0.7243 - val_accuracy: 0.9048
# Epoch 220/800
# 2/2 [==============================] - 0s 63ms/step - loss: 2.4888e-07 - accuracy: 1.0000 - val_loss: 0.7253 - val_accuracy: 0.9048
# Epoch 221/800
# 2/2 [==============================] - 0s 65ms/step - loss: 2.4783e-07 - accuracy: 1.0000 - val_loss: 0.7258 - val_accuracy: 0.9048
# Epoch 222/800
# 2/2 [==============================] - 0s 70ms/step - loss: 2.4678e-07 - accuracy: 1.0000 - val_loss: 0.7259 - val_accuracy: 0.9048
# Epoch 223/800
# 2/2 [==============================] - 0s 66ms/step - loss: 2.4678e-07 - accuracy: 1.0000 - val_loss: 0.7258 - val_accuracy: 0.9048
# Epoch 224/800
# 2/2 [==============================] - 0s 67ms/step - loss: 2.4678e-07 - accuracy: 1.0000 - val_loss: 0.7256 - val_accuracy: 0.9048
# Epoch 225/800
# 2/2 [==============================] - 0s 63ms/step - loss: 2.4469e-07 - accuracy: 1.0000 - val_loss: 0.7253 - val_accuracy: 0.9048
# Epoch 226/800
# 2/2 [==============================] - 0s 65ms/step - loss: 2.4365e-07 - accuracy: 1.0000 - val_loss: 0.7252 - val_accuracy: 0.9048
# Epoch 227/800
# 2/2 [==============================] - 0s 72ms/step - loss: 2.4365e-07 - accuracy: 1.0000 - val_loss: 0.7251 - val_accuracy: 0.9048
# Epoch 228/800
# 2/2 [==============================] - 0s 66ms/step - loss: 2.4365e-07 - accuracy: 1.0000 - val_loss: 0.7249 - val_accuracy: 0.9048
# Epoch 229/800
# 2/2 [==============================] - 0s 73ms/step - loss: 2.4365e-07 - accuracy: 1.0000 - val_loss: 0.7248 - val_accuracy: 0.9048
# Epoch 230/800
# 2/2 [==============================] - 0s 74ms/step - loss: 2.4051e-07 - accuracy: 1.0000 - val_loss: 0.7251 - val_accuracy: 0.9048
# Epoch 231/800
# 2/2 [==============================] - 0s 67ms/step - loss: 2.3946e-07 - accuracy: 1.0000 - val_loss: 0.7268 - val_accuracy: 0.9048
# Epoch 232/800
# 2/2 [==============================] - 0s 66ms/step - loss: 2.3842e-07 - accuracy: 1.0000 - val_loss: 0.7280 - val_accuracy: 0.9048
# Epoch 233/800
# 2/2 [==============================] - 0s 72ms/step - loss: 2.3842e-07 - accuracy: 1.0000 - val_loss: 0.7287 - val_accuracy: 0.9048
# Epoch 234/800
# 2/2 [==============================] - 0s 72ms/step - loss: 2.3842e-07 - accuracy: 1.0000 - val_loss: 0.7290 - val_accuracy: 0.9048
# Epoch 235/800
# 2/2 [==============================] - 0s 71ms/step - loss: 2.3842e-07 - accuracy: 1.0000 - val_loss: 0.7292 - val_accuracy: 0.9048
# Epoch 236/800
# 2/2 [==============================] - 0s 71ms/step - loss: 2.3633e-07 - accuracy: 1.0000 - val_loss: 0.7292 - val_accuracy: 0.9048
# Epoch 237/800
# 2/2 [==============================] - 0s 71ms/step - loss: 2.3633e-07 - accuracy: 1.0000 - val_loss: 0.7292 - val_accuracy: 0.9048
# Epoch 238/800
# 2/2 [==============================] - 0s 67ms/step - loss: 2.3528e-07 - accuracy: 1.0000 - val_loss: 0.7292 - val_accuracy: 0.9048
# Epoch 239/800
# 2/2 [==============================] - 0s 71ms/step - loss: 2.3528e-07 - accuracy: 1.0000 - val_loss: 0.7295 - val_accuracy: 0.9048
# Epoch 240/800
# 2/2 [==============================] - 0s 71ms/step - loss: 2.3424e-07 - accuracy: 1.0000 - val_loss: 0.7295 - val_accuracy: 0.9048
# Epoch 241/800
# 2/2 [==============================] - 0s 75ms/step - loss: 2.3319e-07 - accuracy: 1.0000 - val_loss: 0.7296 - val_accuracy: 0.9048
# Epoch 242/800
# 2/2 [==============================] - 0s 77ms/step - loss: 2.3319e-07 - accuracy: 1.0000 - val_loss: 0.7294 - val_accuracy: 0.9048
# Epoch 243/800
# 2/2 [==============================] - 0s 71ms/step - loss: 2.3110e-07 - accuracy: 1.0000 - val_loss: 0.7291 - val_accuracy: 0.9048
# Epoch 244/800
# 2/2 [==============================] - 0s 65ms/step - loss: 2.3005e-07 - accuracy: 1.0000 - val_loss: 0.7289 - val_accuracy: 0.9048
# Epoch 245/800
# 2/2 [==============================] - 0s 72ms/step - loss: 2.3005e-07 - accuracy: 1.0000 - val_loss: 0.7291 - val_accuracy: 0.9048
# Epoch 246/800
# 2/2 [==============================] - 0s 73ms/step - loss: 2.2901e-07 - accuracy: 1.0000 - val_loss: 0.7297 - val_accuracy: 0.9048
# Epoch 247/800
# 2/2 [==============================] - 0s 72ms/step - loss: 2.2692e-07 - accuracy: 1.0000 - val_loss: 0.7300 - val_accuracy: 0.9048
# Epoch 248/800
# 2/2 [==============================] - 0s 67ms/step - loss: 2.2692e-07 - accuracy: 1.0000 - val_loss: 0.7302 - val_accuracy: 0.9048
# Epoch 249/800
# 2/2 [==============================] - 0s 65ms/step - loss: 2.2692e-07 - accuracy: 1.0000 - val_loss: 0.7303 - val_accuracy: 0.9048
# Epoch 250/800
# 2/2 [==============================] - 0s 72ms/step - loss: 2.2587e-07 - accuracy: 1.0000 - val_loss: 0.7304 - val_accuracy: 0.9048
# Epoch 251/800
# 2/2 [==============================] - 0s 69ms/step - loss: 2.2587e-07 - accuracy: 1.0000 - val_loss: 0.7308 - val_accuracy: 0.9048
# Epoch 252/800
# 2/2 [==============================] - 0s 73ms/step - loss: 2.2482e-07 - accuracy: 1.0000 - val_loss: 0.7311 - val_accuracy: 0.9048
# Epoch 253/800
# 2/2 [==============================] - 0s 67ms/step - loss: 2.2482e-07 - accuracy: 1.0000 - val_loss: 0.7316 - val_accuracy: 0.9048
# Epoch 254/800
# 2/2 [==============================] - 0s 69ms/step - loss: 2.2482e-07 - accuracy: 1.0000 - val_loss: 0.7320 - val_accuracy: 0.9048
# Epoch 255/800
# 2/2 [==============================] - 0s 81ms/step - loss: 2.2482e-07 - accuracy: 1.0000 - val_loss: 0.7323 - val_accuracy: 0.9048
# Epoch 256/800
# 2/2 [==============================] - 0s 70ms/step - loss: 2.2169e-07 - accuracy: 1.0000 - val_loss: 0.7322 - val_accuracy: 0.9048
# Epoch 257/800
# 2/2 [==============================] - 0s 70ms/step - loss: 2.2273e-07 - accuracy: 1.0000 - val_loss: 0.7323 - val_accuracy: 0.9048
# Epoch 258/800
# 2/2 [==============================] - 0s 74ms/step - loss: 2.1960e-07 - accuracy: 1.0000 - val_loss: 0.7334 - val_accuracy: 0.9048
# Epoch 259/800
# 2/2 [==============================] - 0s 84ms/step - loss: 2.1960e-07 - accuracy: 1.0000 - val_loss: 0.7341 - val_accuracy: 0.9048
# Epoch 260/800
# 2/2 [==============================] - 0s 65ms/step - loss: 2.1855e-07 - accuracy: 1.0000 - val_loss: 0.7345 - val_accuracy: 0.9048
# Epoch 261/800
# 2/2 [==============================] - 0s 72ms/step - loss: 2.1750e-07 - accuracy: 1.0000 - val_loss: 0.7350 - val_accuracy: 0.9048
# Epoch 262/800
# 2/2 [==============================] - 0s 67ms/step - loss: 2.1646e-07 - accuracy: 1.0000 - val_loss: 0.7353 - val_accuracy: 0
800
# 2/2 [==============================] - 0s 69ms/step - loss: 1.9764e-07 - accuracy: 1.0000 - val_loss: 0.7405 - val_accuracy: 0.9048
# Epoch 288/800
# 2/2 [==============================] - 0s 71ms/step - loss: 1.9764e-07 - accuracy: 1.0000 - val_loss: 0.7412 - val_accuracy: 0.9048
# Epoch 289/800
# 2/2 [==============================] - 0s 70ms/step - loss: 1.9764e-07 - accuracy: 1.0000 - val_loss: 0.7416 - val_accuracy: 0.9048
# Epoch 290/800
# 2/2 [==============================] - 0s 73ms/step - loss: 1.9659e-07 - accuracy: 1.0000 - val_loss: 0.7415 - val_accuracy: 0.9048
# Epoch 291/800
# 2/2 [==============================] - 0s 69ms/step - loss: 1.9554e-07 - accuracy: 1.0000 - val_loss: 0.7415 - val_accuracy: 0.9048
# Epoch 292/800
# 2/2 [==============================] - 0s 72ms/step - loss: 1.9450e-07 - accuracy: 1.0000 - val_loss: 0.7417 - val_accuracy: 0.9048
# Epoch 293/800
# 2/2 [==============================] - 0s 76ms/step - loss: 1.9345e-07 - accuracy: 1.0000 - val_loss: 0.7419 - val_accuracy: 0.9048
# Epoch 294/800
# 2/2 [==============================] - 0s 70ms/step - loss: 1.9345e-07 - accuracy: 1.0000 - val_loss: 0.7418 - val_accuracy: 0.9048
# Epoch 295/800
# 2/2 [==============================] - 0s 71ms/step - loss: 1.9345e-07 - accuracy: 1.0000 - val_loss: 0.7422 - val_accuracy: 0.9048
# Epoch 296/800
# 2/2 [==============================] - 0s 77ms/step - loss: 1.9345e-07 - accuracy: 1.0000 - val_loss: 0.7429 - val_accuracy: 0.9048
# Epoch 297/800
# 2/2 [==============================] - 0s 72ms/step - loss: 1.9345e-07 - accuracy: 1.0000 - val_loss: 0.7432 - val_accuracy: 0.9048
# Epoch 298/800
# 2/2 [==============================] - 0s 67ms/step - loss: 1.9241e-07 - accuracy: 1.0000 - val_loss: 0.7433 - val_accuracy: 0.9048
# Epoch 299/800
# 2/2 [==============================] - 0s 69ms/step - loss: 1.9136e-07 - accuracy: 1.0000 - val_loss: 0.7434 - val_accuracy: 0.9048
# Epoch 300/800
# 2/2 [==============================] - 0s 64ms/step - loss: 1.9032e-07 - accuracy: 1.0000 - val_loss: 0.7434 - val_accuracy: 0.9048
# Epoch 301/800
# 2/2 [==============================] - 0s 73ms/step - loss: 1.9032e-07 - accuracy: 1.0000 - val_loss: 0.7436 - val_accuracy: 0.9048
# Epoch 302/800
# 2/2 [==============================] - 0s 72ms/step - loss: 1.9032e-07 - accuracy: 1.0000 - val_loss: 0.7444 - val_accuracy: 0.9048
# Epoch 303/800
# 2/2 [==============================] - 0s 68ms/step - loss: 1.8927e-07 - accuracy: 1.0000 - val_loss: 0.7448 - val_accuracy: 0.9048
# Epoch 304/800
# 2/2 [==============================] - 0s 68ms/step - loss: 1.8927e-07 - accuracy: 1.0000 - val_loss: 0.7448 - val_accuracy: 0.9048
# Epoch 305/800
# 2/2 [==============================] - 0s 74ms/step - loss: 1.8822e-07 - accuracy: 1.0000 - val_loss: 0.7447 - val_accuracy: 0.9048
# Epoch 306/800
# 2/2 [==============================] - 0s 68ms/step - loss: 1.8822e-07 - accuracy: 1.0000 - val_loss: 0.7448 - val_accuracy: 0.9048
# Epoch 307/800
# 2/2 [==============================] - 0s 70ms/step - loss: 1.8822e-07 - accuracy: 1.0000 - val_loss: 0.7452 - val_accuracy: 0.9048
# Epoch 308/800
# 2/2 [==============================] - 0s 72ms/step - loss: 1.8822e-07 - accuracy: 1.0000 - val_loss: 0.7463 - val_accuracy: 0.9048
# Epoch 309/800
# 2/2 [==============================] - 0s 84ms/step - loss: 1.8718e-07 - accuracy: 1.0000 - val_loss: 0.7470 - val_accuracy: 0.9048
# Epoch 310/800
# 2/2 [==============================] - 0s 73ms/step - loss: 1.8718e-07 - accuracy: 1.0000 - val_loss: 0.7472 - val_accuracy: 0.9048
# Epoch 311/800
# 2/2 [==============================] - 0s 70ms/step - loss: 1.8613e-07 - accuracy: 1.0000 - val_loss: 0.7472 - val_accuracy: 0.9048
# Epoch 312/800
# 2/2 [==============================] - 0s 69ms/step - loss: 1.8509e-07 - accuracy: 1.0000 - val_loss: 0.7471 - val_accuracy: 0.9048
# Epoch 313/800
# 2/2 [==============================] - 0s 79ms/step - loss: 1.8195e-07 - accuracy: 1.0000 - val_loss: 0.7469 - val_accuracy: 0.9048
# Epoch 314/800
# 2/2 [==============================] - 0s 75ms/step - loss: 1.8195e-07 - accuracy: 1.0000 - val_loss: 0.7469 - val_accuracy: 0.9048
# Epoch 315/800
# 2/2 [==============================] - 0s 65ms/step - loss: 1.8195e-07 - accuracy: 1.0000 - val_loss: 0.7468 - val_accuracy: 0.9048
# Epoch 316/800
# 2/2 [==============================] - 0s 65ms/step - loss: 1.8195e-07 - accuracy: 1.0000 - val_loss: 0.7467 - val_accuracy: 0.9048
# Epoch 317/800
# 2/2 [==============================] - 0s 77ms/step - loss: 1.8195e-07 - accuracy: 1.0000 - val_loss: 0.7471 - val_accuracy: 0.9048
# Epoch 318/800
# 2/2 [==============================] - 0s 72ms/step - loss: 1.8195e-07 - accuracy: 1.0000 - val_loss: 0.7476 - val_accuracy: 0.9048
# Epoch 319/800
# 2/2 [==============================] - 0s 85ms/step - loss: 1.8195e-07 - accuracy: 1.0000 - val_loss: 0.7485 - val_accuracy: 0.9048
# Epoch 320/800
# 2/2 [==============================] - 0s 83ms/step - loss: 1.8091e-07 - accuracy: 1.0000 - val_loss: 0.7492 - val_accuracy: 0.9048
# Epoch 321/800
# 2/2 [==============================] - 0s 63ms/step - loss: 1.8091e-07 - accuracy: 1.0000 - val_loss: 0.7496 - val_accuracy: 0.9048
# Epoch 322/800
# 2/2 [==============================] - 0s 69ms/step - loss: 1.8091e-07 - accuracy: 1.0000 - val_loss: 0.7496 - val_accuracy: 0.9048
# Epoch 323/800
# 2/2 [==============================] - 0s 69ms/step - loss: 1.8091e-07 - accuracy: 1.0000 - val_loss: 0.7494 - val_accuracy: 0.9048
# Epoch 324/800
# 2/2 [==============================] - 0s 70ms/step - loss: 1.8091e-07 - accuracy: 1.0000 - val_loss: 0.7492 - val_accuracy: 0.9048
# Epoch 325/800
# 2/2 [==============================] - 0s 66ms/step - loss: 1.8091e-07 - accuracy: 1.0000 - val_loss: 0.7494 - val_accuracy: 0.9048
# Epoch 326/800
# 2/2 [==============================] - 0s 67ms/step - loss: 1.8091e-07 - accuracy: 1.0000 - val_loss: 0.7498 - val_accuracy: 0.9048
# Epoch 327/800
# 2/2 [==============================] - 0s 70ms/step - loss: 1.7881e-07 - accuracy: 1.0000 - val_loss: 0.7506 - val_accuracy: 0.9048
# Epoch 328/800
# 2/2 [==============================] - 0s 69ms/step - loss: 1.7777e-07 - accuracy: 1.0000 - val_loss: 0.7513 - val_accuracy: 0.9048
# Epoch 329/800
# 2/2 [==============================] - 0s 69ms/step - loss: 1.7672e-07 - accuracy: 1.0000 - val_loss: 0.7517 - val_accuracy: 0.9048
# Epoch 330/800
# ...
# Epoch 692/800
# 2/2 [==============================] - 0s 69ms/step - loss: 5.0193e-08 - accuracy: 1.0000 - val_loss: 0.8747 - val_accuracy: 0.9048
# Epoch 693/800
# 2/2 [==============================] - 0s 82ms/step - loss: 5.0193e-08 - accuracy: 1.0000 - val_loss: 0.8748 - val_accuracy: 0.9048
# Epoch 694/800
# 2/2 [==============================] - 0s 68ms/step - loss: 5.0193e-08 - accuracy: 1.0000 - val_loss: 0.8749 - val_accuracy: 0.9048
# Epoch 695/800
# 2/2 [==============================] - 0s 70ms/step - loss: 5.1239e-08 - accuracy: 1.0000 - val_loss: 0.8750 - val_accuracy: 0.9048
# Epoch 696/800
# 2/2 [==============================] - 0s 72ms/step - loss: 4.9148e-08 - accuracy: 1.0000 - val_loss: 0.8753 - val_accuracy: 0.9048
# Epoch 697/800
# 2/2 [==============================] - 0s 69ms/step - loss: 5.0193e-08 - accuracy: 1.0000 - val_loss: 0.8755 - val_accuracy: 0.9048
# Epoch 698/800
# 2/2 [==============================] - 0s 69ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8756 - val_accuracy: 0.9048
# Epoch 699/800
# 2/2 [==============================] - 0s 75ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8760 - val_accuracy: 0.9048
# Epoch 700/800
# 2/2 [==============================] - 0s 72ms/step - loss: 4.8102e-08 - accuracy: 1.0000 - val_loss: 0.8762 - val_accuracy: 0.9048
# Epoch 701/800
# 2/2 [==============================] - 0s 75ms/step - loss: 4.8102e-08 - accuracy: 1.0000 - val_loss: 0.8763 - val_accuracy: 0.9048
# Epoch 702/800
# 2/2 [==============================] - 0s 78ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8764 - val_accuracy: 0.9048
# Epoch 703/800
# 2/2 [==============================] - 0s 70ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8765 - val_accuracy: 0.9048
# Epoch 704/800
# 2/2 [==============================] - 0s 72ms/step - loss: 4.8102e-08 - accuracy: 1.0000 - val_loss: 0.8767 - val_accuracy: 0.9048
# Epoch 705/800
# 2/2 [==============================] - 0s 80ms/step - loss: 4.8102e-08 - accuracy: 1.0000 - val_loss: 0.8771 - val_accuracy: 0.9048
# Epoch 706/800
# 2/2 [==============================] - 0s 70ms/step - loss: 4.8102e-08 - accuracy: 1.0000 - val_loss: 0.8774 - val_accuracy: 0.9048
# Epoch 707/800
# 2/2 [==============================] - 0s 68ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8776 - val_accuracy: 0.9048
# Epoch 708/800
# 2/2 [==============================] - 0s 73ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8777 - val_accuracy: 0.9048
# Epoch 709/800
# 2/2 [==============================] - 0s 75ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8777 - val_accuracy: 0.9048
# Epoch 710/800
# 2/2 [==============================] - 0s 75ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8778 - val_accuracy: 0.9048
# Epoch 711/800
# 2/2 [==============================] - 0s 72ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8779 - val_accuracy: 0.9048
# Epoch 712/800
# 2/2 [==============================] - 0s 75ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8777 - val_accuracy: 0.9048
# Epoch 713/800
# 2/2 [==============================] - 0s 81ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8779 - val_accuracy: 0.9048
# Epoch 714/800
# 2/2 [==============================] - 0s 85ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8782 - val_accuracy: 0.9048
# Epoch 715/800
# 2/2 [==============================] - 0s 66ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8786 - val_accuracy: 0.9048
# Epoch 716/800
# 2/2 [==============================] - 0s 71ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8789 - val_accuracy: 0.9048
# Epoch 717/800
# 2/2 [==============================] - 0s 79ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8791 - val_accuracy: 0.9048
# Epoch 718/800
# 2/2 [==============================] - 0s 73ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8792 - val_accuracy: 0.9048
# Epoch 719/800
# 2/2 [==============================] - 0s 74ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8794 - val_accuracy: 0.9048
# Epoch 720/800
# 2/2 [==============================] - 0s 69ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8794 - val_accuracy: 0.9048
# Epoch 721/800
# 2/2 [==============================] - 0s 71ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8794 - val_accuracy: 0.9048
# Epoch 722/800
# 2/2 [==============================] - 0s 79ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8794 - val_accuracy: 0.9048
# Epoch 723/800
# 2/2 [==============================] - 0s 70ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8797 - val_accuracy: 0.9048
# Epoch 724/800
# 2/2 [==============================] - 0s 75ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8801 - val_accuracy: 0.9048
# Epoch 725/800
# 2/2 [==============================] - 0s 70ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8804 - val_accuracy: 0.9048
# Epoch 726/800
# 2/2 [==============================] - 0s 69ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8805 - val_accuracy: 0.9048
# Epoch 727/800
# 2/2 [==============================] - 0s 77ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8807 - val_accuracy: 0.9048
# Epoch 728/800
# 2/2 [==============================] - 0s 80ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8807 - val_accuracy: 0.9048
# Epoch 729/800
# 2/2 [==============================] - 0s 85ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8808 - val_accuracy: 0.9048
# Epoch 730/800
# 2/2 [==============================] - 0s 73ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8808 - val_accuracy: 0.9048
# Epoch 731/800
# 2/2 [==============================] - 0s 74ms/step - loss: 4.7056e-08 - accuracy: 1.0000 - val_loss: 0.8810 - val_accuracy: 0.9048
# Epoch 732/800
# 2/2 [==============================] - 0s 73ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8815 - val_accuracy: 0.9048
# Epoch 733/800
# 2/2 [==============================] - 0s 69ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8819 - val_accuracy: 0.9048
# Epoch 734/800
# 2/2 [==============================] - 0s 76ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8822 - val_accuracy: 0.9048
# Epoch 735/800
# 2/2 [==============================] - 0s 71ms/step - loss: 4.4965e-08 - accuracy: 1.0000 - val_loss: 0.8824 - val_accuracy: 0.9048
# Epoch 736/800
# 2/2 [==============================] - 0s 73ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8826 - val_accuracy: 0.9048
# Epoch 737/800
# 2/2 [==============================] - 0s 77ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8827 - val_accuracy: 0.9048
# Epoch 738/800
# 2/2 [==============================] - 0s 69ms/step - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.8826 - val_accuracy: 0.9048
# Epoch 739/800
# 2/2 [==============================] - 0s 74ms/step - loss: 4.4965e-08 - accuracy: 1.0000 - val_loss: 0.8826 - val_accuracy: 0.9048
# Epoch 740/800
# 2/2 [==============================] - 0s 85ms/step - loss: 4.3919e-08 - accuracy: 1.0000 - val_loss: 0.8825 - val_accuracy: 0.9048
# Epoch 741/800
# 2/2 [==============================] - 0s 74ms/step - loss: 4.3919e-08 - accuracy: 1.0000 - val_loss: 0.8823 - val_accuracy: 0.9048
# Epoch 742/800
# 2/2 [==============================] - 0s 72ms/step - loss: 4.2874e-08 - accuracy: 1.0000 - val_loss: 0.8825 - val_accuracy: 0.9048
# Epoch 743/800
# 2/2 [==============================] - 0s 78ms/step - loss: 4.3919e-08 - accuracy: 1.0000 - val_loss: 0.8831 - val_accuracy: 0.9048
# Epoch 744/800
# 2/2 [==============================] - 0s 72ms/step - loss: 4.2874e-08 - accuracy: 1.0000 - val_loss: 0.8835 - val_accuracy: 0.9048
# Epoch 745/800
# 2/2 [==============================] - 0s 73ms/step - loss: 4.2874e-08 - accuracy: 1.0000 - val_loss: 0.8838 - val_accuracy: 0.9048
# Epoch 746/800
# 2/2 [==============================] - 0s 70ms/step - loss: 4.2874e-08 - accuracy: 1.0000 - val_loss: 0.8841 - val_accuracy: 0.9048
# Epoch 747/800
# 2/2 [==============================] - 0s 76ms/step - loss: 4.3919e-08 - accuracy: 1.0000 - val_loss: 0.8843 - val_accuracy: 0.9048
# Epoch 748/800
# 2/2 [==============================] - 0s 70ms/step - loss: 4.3919e-08 - accuracy: 1.0000 - val_loss: 0.8844 - val_accuracy: 0.9048
# Epoch 749/800
# 2/2 [==============================] - 0s 70ms/step - loss: 4.3919e-08 - accuracy: 1.0000 - val_loss: 0.8845 - val_accuracy: 0.9048
# Epoch 750/800
# 2/2 [==============================] - 0s 70ms/step - loss: 4.3919e-08 - accuracy: 1.0000 - val_loss: 0.8844 - val_accuracy: 0.9048
# Epoch 751/800
# 2/2 [==============================] - 0s 78ms/step - loss: 4.2874e-08 - accuracy: 1.0000 - val_loss: 0.8844 - val_accuracy: 0.9048
# Epoch 752/800
# 2/2 [==============================] - 0s 73ms/step - loss: 4.2874e-08 - accuracy: 1.0000 - val_loss: 0.8844 - val_accuracy: 0.9048
# Epoch 753/800
# 2/2 [==============================] - 0s 73ms/step - loss: 4.2874e-08 - accuracy: 1.0000 - val_loss: 0.8845 - val_accuracy: 0.9048
# Epoch 754/800
# 2/2 [==============================] - 0s 74ms/step - loss: 4.3919e-08 - accuracy: 1.0000 - val_loss: 0.8845 - val_accuracy: 0.9048
# Epoch 755/800
# 2/2 [==============================] - 0s 73ms/step - loss: 4.2874e-08 - accuracy: 1.0000 - val_loss: 0.8844 - val_accuracy: 0.9048
# Epoch 756/800
# 2/2 [==============================] - 0s 68ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8845 - val_accuracy: 0.9048
# Epoch 757/800
# 2/2 [==============================] - 0s 73ms/step - loss: 4.2874e-08 - accuracy: 1.0000 - val_loss: 0.8848 - val_accuracy: 0.9048
# Epoch 758/800
# 2/2 [==============================] - 0s 69ms/step - loss: 4.2874e-08 - accuracy: 1.0000 - val_loss: 0.8850 - val_accuracy: 0.9048
# Epoch 759/800
# 2/2 [==============================] - 0s 78ms/step - loss: 4.2874e-08 - accuracy: 1.0000 - val_loss: 0.8852 - val_accuracy: 0.9048
# Epoch 760/800
# 2/2 [==============================] - 0s 72ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8853 - val_accuracy: 0.9048
# Epoch 761/800
# 2/2 [==============================] - 0s 76ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8853 - val_accuracy: 0.9048
# Epoch 762/800
# 2/2 [==============================] - 0s 96ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8855 - val_accuracy: 0.9048
# Epoch 763/800
# 2/2 [==============================] - 0s 81ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8855 - val_accuracy: 0.9048
# Epoch 764/800
# 2/2 [==============================] - 0s 71ms/step - loss: 4.2874e-08 - accuracy: 1.0000 - val_loss: 0.8855 - val_accuracy: 0.9048
# Epoch 765/800
# 2/2 [==============================] - 0s 71ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8858 - val_accuracy: 0.9048
# Epoch 766/800
# 2/2 [==============================] - 0s 74ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8860 - val_accuracy: 0.9048
# Epoch 767/800
# 2/2 [==============================] - 0s 72ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8861 - val_accuracy: 0.9048
# Epoch 768/800
# 2/2 [==============================] - 0s 80ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8862 - val_accuracy: 0.9048
# Epoch 769/800
# 2/2 [==============================] - 0s 73ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8864 - val_accuracy: 0.9048
# Epoch 770/800
# 2/2 [==============================] - 0s 71ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8865 - val_accuracy: 0.9048
# Epoch 771/800
# 2/2 [==============================] - 0s 78ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8865 - val_accuracy: 0.9048
# Epoch 772/800
# 2/2 [==============================] - 0s 75ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8866 - val_accuracy: 0.9048
# Epoch 773/800
# 2/2 [==============================] - 0s 71ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8869 - val_accuracy: 0.9048
# Epoch 774/800
# 2/2 [==============================] - 0s 71ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8870 - val_accuracy: 0.9048
# Epoch 775/800
# 2/2 [==============================] - 0s 78ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8872 - val_accuracy: 0.9048
# Epoch 776/800
# 2/2 [==============================] - 0s 72ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8873 - val_accuracy: 0.9048
# Epoch 777/800
# 2/2 [==============================] - 0s 80ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8874 - val_accuracy: 0.9048
# Epoch 778/800
# 2/2 [==============================] - 0s 69ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8875 - val_accuracy: 0.9048
# Epoch 779/800
# 2/2 [==============================] - 0s 67ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8875 - val_accuracy: 0.9048
# Epoch 780/800
# 2/2 [==============================] - 0s 76ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8875 - val_accuracy: 0.9048
# Epoch 781/800
# 2/2 [==============================] - 0s 75ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8874 - val_accuracy: 0.9048
# Epoch 782/800
# 2/2 [==============================] - 0s 77ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8876 - val_accuracy: 0.9048
# Epoch 783/800
# 2/2 [==============================] - 0s 79ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8877 - val_accuracy: 0.9048
# Epoch 784/800
# 2/2 [==============================] - 0s 66ms/step - loss: 4.1828e-08 - accuracy: 1.0000 - val_loss: 0.8879 - val_accuracy: 0.9048
# Epoch 785/800
# 2/2 [==============================] - 0s 70ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8879 - val_accuracy: 0.9048
# Epoch 786/800
# 2/2 [==============================] - 0s 82ms/step - loss: 3.9736e-08 - accuracy: 1.0000 - val_loss: 0.8880 - val_accuracy: 0.9048
# Epoch 787/800
# 2/2 [==============================] - 0s 81ms/step - loss: 3.9736e-08 - accuracy: 1.0000 - val_loss: 0.8881 - val_accuracy: 0.9048
# Epoch 788/800
# 2/2 [==============================] - 0s 70ms/step - loss: 3.9736e-08 - accuracy: 1.0000 - val_loss: 0.8883 - val_accuracy: 0.9048
# Epoch 789/800
# 2/2 [==============================] - 0s 73ms/step - loss: 3.9736e-08 - accuracy: 1.0000 - val_loss: 0.8885 - val_accuracy: 0.9048
# Epoch 790/800
# 2/2 [==============================] - 0s 72ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8887 - val_accuracy: 0.9048
# Epoch 791/800
# 2/2 [==============================] - 0s 69ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8888 - val_accuracy: 0.9048
# Epoch 792/800
# 2/2 [==============================] - 0s 69ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8890 - val_accuracy: 0.9048
# Epoch 793/800
# 2/2 [==============================] - 0s 75ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8890 - val_accuracy: 0.9048
# Epoch 794/800
# 2/2 [==============================] - 0s 73ms/step - loss: 3.9736e-08 - accuracy: 1.0000 - val_loss: 0.8889 - val_accuracy: 0.9048
# Epoch 795/800
# 2/2 [==============================] - 0s 69ms/step - loss: 3.9736e-08 - accuracy: 1.0000 - val_loss: 0.8888 - val_accuracy: 0.9048
# Epoch 796/800
# 2/2 [==============================] - 0s 71ms/step - loss: 3.9736e-08 - accuracy: 1.0000 - val_loss: 0.8887 - val_accuracy: 0.9048
# Epoch 797/800
# 2/2 [==============================] - 0s 72ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8889 - val_accuracy: 0.9048
# Epoch 798/800
# 2/2 [==============================] - 0s 72ms/step - loss: 4.0782e-08 - accuracy: 1.0000 - val_loss: 0.8897 - val_accuracy: 0.9048
# Epoch 799/800
# 2/2 [==============================] - 0s 77ms/step - loss: 3.9736e-08 - accuracy: 1.0000 - val_loss: 0.8904 - val_accuracy: 0.9048
# Epoch 800/800
# 2/2 [==============================] - 0s 68ms/step - loss: 3.9736e-08 - accuracy: 1.0000 - val_loss: 0.8909 - val_accuracy: 0.9048

# %% [markdown]
# #### Plot the learning curves
#
# We will now plot two graphs:
# * Epoch vs accuracy
# * Epoch vs loss

# %%
#Run this cell to plot the epoch vs accuracy graph

try:
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
except KeyError:
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
#Run this cell to plot the epoch vs loss graph
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# Oh no! We have overfit our dataset. You should now try to now try to mitigate this overfitting.

# %% [markdown]
# #### Reducing overfitting in the model

# %% [markdown]
# You should now define a new regularised model.
# The specs for the regularised model are the same as our original model, with the addition of two dropout layers, weight decay, and a batch normalisation layer.
#
# In particular:
#
# * Add a dropout layer after the 3rd Dense layer
# * Then there should be two more Dense layers with 128 units before a batch normalisation layer
# * Following this, two more Dense layers with 64 units and then another Dropout layer
# * Two more Dense layers with 64 units and then the final 3-way softmax layer
# * Add weight decay (l2 kernel regularisation) in all Dense layers except the final softmax layer

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_regularised_model(input_shape, dropout_rate, weight_decay):
    """
    This function should build a regularised Sequential model according to the above specification. 
    The dropout_rate argument in the function should be used to set the Dropout rate for all Dropout layers.
    L2 kernel regularisation (weight decay) should be added using the weight_decay argument to 
    set the weight decay coefficient in all Dense layers that use L2 regularisation.
    Ensure the weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument input_shape.
    Your function should return the model.
    """
    model = Sequential([
        Dense(64, activation = 'relu', kernel_initializer='he_uniform',bias_initializer='ones', input_shape = input_shape,),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(3, activation='softmax'),
    ])    
    return model

# %% [markdown]
# #### Instantiate, compile and train the model

# %%
# Instantiate the model, using a dropout rate of 0.3 and weight decay coefficient of 0.001

reg_model = get_regularised_model(train_data[0].shape, 0.3, 0.001)

# %%
# Compile the model

compile_model(reg_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-66194594a492> in <module>()
#       1 # Compile the model
#       2
# ----> 3 compile_model(reg_model)
#
# <ipython-input-84-0fd9264fefbf> in compile_model(model)
#      13     Your function doesn't need to return anything; the model will be compiled in-place.
#      14     """
# ---> 15     model.compile(optimizer = Adam(learning_rate=0.001), loss = categorical_crossentropy, metrics = ['accuracy'])
#
# AttributeError: 'NoneType' object has no attribute 'compile'

# %%
# Train the model

reg_history = train_model(reg_model, train_data, train_targets, epochs=800)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-6807e981b040> in <module>()
#       1 # Train the model
#       2
# ----> 3 reg_history = train_model(reg_model, train_data, train_targets, epochs=800)
#
# <ipython-input-91-548875adc679> in train_model(model, train_data, train_targets, epochs)
#      10     Your function should return the training history, as returned by model.fit.
#      11     """
# ---> 12     history = model.fit(train_data, train_targets, batch_size=64, epochs=epochs, validation_split=0.15)
#      13     return history
#
# AttributeError: 'NoneType' object has no attribute 'fit'

# %% [markdown]
# #### Plot the learning curves
#
# Let's now plot the loss and accuracy for the training and validation sets.

# %%
#Run this cell to plot the new accuracy vs epoch graph

try:
    plt.plot(reg_history.history['accuracy'])
    plt.plot(reg_history.history['val_accuracy'])
except KeyError:
    plt.plot(reg_history.history['acc'])
    plt.plot(reg_history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
#Run this cell to plot the new loss vs epoch graph

plt.plot(reg_history.history['loss'])
plt.plot(reg_history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# We can see that the regularisation has helped to reduce the overfitting of the network.
# You will now incorporate callbacks into a new training run that implements early stopping and learning rate reduction on plateaux.
#
# Fill in the function below so that:
#
# * It creates an `EarlyStopping` callback object and a `ReduceLROnPlateau` callback object
# * The early stopping callback is used and monitors validation loss with the mode set to `"min"` and patience of 30.
# * The learning rate reduction on plateaux is used with a learning rate factor of 0.2 and a patience of 20.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_callbacks():
    """
    This function should create and return a tuple (early_stopping, learning_rate_reduction) callbacks.
    The callbacks should be instantiated according to the above requirements.
    """

# %% [markdown]
# Run the cell below to instantiate and train the regularised model with the callbacks.

# %%
call_model = get_regularised_model(train_data[0].shape, 0.3, 0.0001)
compile_model(call_model)
early_stopping, learning_rate_reduction = get_callbacks()
call_history = call_model.fit(train_data, train_targets, epochs=800, validation_split=0.15,
                         callbacks=[early_stopping, learning_rate_reduction], verbose=0)

# %%
learning_rate_reduction.patience

# %% [markdown]
# Finally, let's replot the accuracy and loss graphs for our new model.

# %%
try:
    plt.plot(call_history.history['accuracy'])
    plt.plot(call_history.history['val_accuracy'])
except KeyError:
    plt.plot(call_history.history['acc'])
    plt.plot(call_history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
plt.plot(call_history.history['loss'])
plt.plot(call_history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
# Evaluate the model on the test set

test_loss, test_acc = call_model.evaluate(test_data, test_targets, verbose=0)
print("Test loss: {:.3f}\nTest accuracy: {:.2f}%".format(test_loss, 100 * test_acc))

# %% [markdown]
# Congratulations for completing this programming assignment! In the next week of the course we will learn how to save and load pre-trained models.
